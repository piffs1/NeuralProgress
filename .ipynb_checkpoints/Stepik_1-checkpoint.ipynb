# %%
#source https://github.com/stacymiller/stepic_neural_networks_public
import numpy as np

# %%
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d as p3
import numpy as np
import random
import time

from functools import partial
from ipywidgets import interact, RadioButtons, IntSlider, FloatSlider, Dropdown, BoundedFloatText
from numpy.linalg import norm

random.seed(42) # начальное состояние генератора случайных чисел, чтобы можно было воспроизводить результаты.

# %%
# %matplotlib inline
data = np.loadtxt("stepic_neural_networks_public\HW_1\data.csv", delimiter=",")
pears = data[:, 2] == 1
for iteration in range(len(pears)):
    print(f"Iteration {iteration+1}: {pears[iteration]}")
# Out:
# Iteration 1: True
# Iteration 2: True
# Iteration 3: True
# Iteration 4: False
# Iteration 5: True
# Iteration 6: True
# Iteration 7: True
# Iteration 8: True
# Iteration 9: False
# Iteration 10: False
# Iteration 11: True
# Iteration 12: True
# Iteration 13: True
# Iteration 14: True
# Iteration 15: True
# Iteration 16: True
# Iteration 17: True
# Iteration 18: True
# Iteration 19: True
# Iteration 20: True
# Iteration 21: False
# Iteration 22: False
# Iteration 23: True
# Iteration 24: True
# Iteration 25: True
# Iteration 26: True
# Iteration 27: False
# Iteration 28: True
# Iteration 29: False
# Iteration 30: False
# Iteration 31: True
# Iteration 32: True
# Iteration 33: False
# Iteration 34: True
# Iteration 35: True
# Iteration 36: True
# Iteration 37: True
# Iteration 38: True
# Iteration 39: True
# Iteration 40: False
# Iteration 41: True
# Iteration 42: True
# Iteration 43: False
# Iteration 44: True
# Iteration 45: False
# Iteration 46: False
# Iteration 47: True
# ...

# %%
plt.scatter(data[apples][:, 0], data[apples][:, 1], color = "red")
plt.scatter(data[pears][:, 0], data[pears][:, 1], color = "green")
plt.xlabel("yellowness")
plt.ylabel("symmetry")
plt.show()

# %%
print(f"Len(data) is {len(data)}")
tpl = data.shape
print(f"Data shape is {tpl[0]}x{tpl[1]}")
print(data)
# Out:
# Len(data) is 1000
# Data shape is 1000x3
# [[0.77942731 0.25730527 1.        ]
#  [0.77700501 0.0159154  1.        ]
#  [0.97709225 0.30420962 1.        ]
#  ...
#  [0.92721921 0.13498618 1.        ]
#  [0.01582991 0.48132194 0.        ]
#  [0.96796389 0.30857107 1.        ]]

# %%
class Perceptron:

    def __init__(self, w, b):
        """
        Инициализируем наш объект - перцептрон.
        w - вектор весов размера (m, 1), где m - количество переменных
        b - число
        """
        
        self.w = w
        self.b = b

    def forward_pass(self, single_input):
        """
        Метод рассчитывает ответ перцептрона при предъявлении одного примера
        single_input - вектор примера размера (m, 1).
        Метод возвращает число (0 или 1) или boolean (True/False)
        """
        
        result = 0
        for i in range(0, len(self.w)):
            result += self.w[i] * single_input[i]
        result += self.b
        
        if result > 0:
            return 1
        else:
            return 0

    def vectorized_forward_pass(self, input_matrix):
        """
        Метод рассчитывает ответ перцептрона при предъявлении набора примеров
        input_matrix - матрица примеров размера (n, m), каждая строка - отдельный пример,
        n - количество примеров, m - количество переменных
        Возвращает вертикальный вектор размера (n, 1) с ответами перцептрона
        (элементы вектора - boolean или целые числа (0 или 1))
        """
        #self.b = Вектор смещения. В данном случае выполнен отдельной переменной
        #self.b доплюсовывает к каждому элементу вектора Nx1
        return input_matrix.dot(self.w) + self.b > 0
    
    def train_on_single_example(self, example, y):
        """
        принимает вектор активации входов example формы (m, 1) 
        и правильный ответ для него (число 0 или 1 или boolean),
        обновляет значения весов перцептрона в соответствии с этим примером
        и возвращает размер ошибки, которая случилась на этом примере до изменения весов (0 или 1)
        (на её основании мы потом построим интересный график)
        """

        ## Этот метод необходимо реализовать
        pass

# %%
# Просто тест
weights = np.array([[0,0,0]]).T
print(weights)
# Out:
# [[0]
#  [0]
#  [0]]
